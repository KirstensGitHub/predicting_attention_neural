# %% [markdown]
# # NEEDS REVIEW AND CLEANUP !
#
# This file is pulled straight from initial pass over data
#
# needs review and cleanup
#
# ulitmately, delete first bunch of cells (after all other notebooks working)

# %% [markdown]
# # Events Files & Timing

# %% [markdown]
# ### Import packages

# %%
import os
import re
import numpy as np
import pandas as pd
import subprocess
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# ### Check length of each run

# %% [markdown]
# #### Function for getting the number of frames in a video

# %%
def get_frames(l):
    '''
    input:  list of movie filepaths
    output: list of # of frames
    '''

    frames = []

    for path in l:
        
        # Define the command
        command = ["ffprobe", "-v", "error", "-select_streams", "v:0", "-count_frames", "-show_entries", "stream=nb_read_frames", "-print_format", "csv", path]
        
        # Execute the command and capture output
        output = subprocess.run(command, capture_output=True).stdout.decode("utf-8")
        
        # Extract the number of frames using regex
        pattern = r"(\d+)"
        match = re.search(pattern, output)
        
        if match:
            number_of_frames = int(match.group(1))
        else:
            number_of_frames = np.nan
            print('could not find number of frames: '+path)

        frames.append(number_of_frames)
    
    return(frames)

# %% [markdown]
# #### Get the duration of each run

# %%
real_timing_dict = {1:{'subject':[],'duration':[], 'run':[]}, 
                    2:{'subject':[],'duration':[], 'run':[]}, 
                    3:{'subject':[],'duration':[], 'run':[]}, 
                    4:{'subject':[],'duration':[], 'run':[]}, 
                    5:{'subject':[],'duration':[], 'run':[]}, 
                    6:{'subject':[],'duration':[], 'run':[]}}

subject_dirs = [x for x in os.listdir('behavioral_data') if 'ubject' in x and 'unusual' not in x
                and 'disregard' not in x]

print(subject_dirs)

# for each person
for s in subject_dirs:
    
    for logfile in os.listdir('behavioral_data/'+s):
        
        # skip non-log files
        if not logfile.endswith('.log'):
            continue

        # load the log file and get run #
        log = pd.read_table('behavioral_data/'+s+'/'+logfile,header=None)

        # provided that there were scan pulses recorded
        
        if log[2].eq('Keypress: equal').any():

            # get run #
            run_line = log[log[2].str.contains('.csv')].iloc[0, 2]
            run = int(re.search('movie_stim_(\d)\.csv', run_line).group(1))
            
            # find onset of first fixation and end of last fixation
            
            
            # exp_start = log[log[2]=='Keypress: equal'].iloc[0][0]
            exp_start = log[log[2]=='fix3: autoDraw = True'][0].unique()[0]
            
            # exp_end = list(log[log[2]=='Keypress: equal'][0])[-1]
            exp_end = log[log[2]=='fix4: autoDraw = False'][0].unique()[0]
    
            # run duration
            duration = exp_end - exp_start

        # else:
        #     duration = np.nan; run = np.nan
    
            # add the total time to dict, in the key for that run (1-6)
            real_timing_dict[run]['subject' ].append(s)
            real_timing_dict[run]['duration'].append(duration)
            real_timing_dict[run]['run'].append(run)
# Out:
# ['subject_17', 'subject_4', 'subject_1', 'subject_9', 'subject_22', 'subject_6', 'subject_21', 'subject_19', 'subject_8', 'subject_14', 'subject_16', 'subject_12', 'subject_11', 'subject_7', 'subject_5', 'subject_2', 'subject_20', 'subject_10', 'subject_15', 'subject_13', 'subject_3', 'subject_18', 'subject_23']

# %%
def int_ending(string):
    return int(re.search(r'\d+$', string).group())

# %%
sb.set_style('whitegrid')

# prep data
big_df = pd.concat([pd.DataFrame(real_timing_dict[x]) for x in [1, 2, 3, 4, 5, 6]])

big_df['sub'] = [int_ending(x) for x in list(big_df['subject'])]

# make plot grid
fig, axes = plt.subplots(2, 3, gridspec_kw={'width_ratios': [4, 4, 4]},figsize=(20,6))

# for each run
for run, axis in zip(list(real_timing_dict.keys()), axes.flatten()):

    # plot a barplot where the x values are the individual subjects, y is the duration
    ax = sb.barplot(y='duration', x='sub', data=big_df[big_df['run']==run], ax=axis)
    ax.set_ylim((210, 220))
    ax.set_yticks(range(210,221))
    ax.set_title('Run '+str(run))
    #ax.set_xticks(rotation=90)
    # ax.set_ylim((214, 219))

# %% [markdown]
# ### Subjects 1-17

# %%
# make plot grid
fig, axes = plt.subplots(2, 3, gridspec_kw={'width_ratios': [4, 4, 4]},figsize=(20,6))

# for each run
for run, axis in zip(list(real_timing_dict.keys()), axes.flatten()):

    # plot a barplot where the x values are the individual subjects, y is the duration
    ax = sb.barplot(y='duration', x='sub', data=big_df[(big_df['run']==run)
                                                      &(big_df['sub'] <= 17)], ax=axis) #, order = order)
    ax.set_ylim((212, 219))
    #ax.set_yticks(range(210,221))
    ax.set_title('Run '+str(run))

# %% [markdown]
# ### Subjects 18-23

# %%
# make plot grid
fig, axes = plt.subplots(2, 3, gridspec_kw={'width_ratios': [4, 4, 4]},figsize=(20,6))

# for each run
for run, axis in zip(list(real_timing_dict.keys()), axes.flatten()):

    # plot a barplot where the x values are the individual subjects, y is the duration
    ax = sb.barplot(y='duration', x='sub', data=big_df[(big_df['run']==run)
                                                      &(big_df['sub'] >= 18)], ax=axis) #, order = order)
    ax.set_ylim((212, 219))
    #ax.set_yticks(range(210,221))
    ax.set_title('Run '+str(run))

# %%
# variation in subjects 18-23
small = big_df[big_df['sub'] >= 18]

# variation in subjects 1-17
big   = big_df[big_df['sub'] <= 17]

for run in range(1,7):
    print(run);print()

    print('small')
    small_durations = small[small['run'] == str(run)]['duration']
    
    print(f"mean time: {np.mean(small_durations):.3f}")
    print(f"min  time: {np.min(small_durations):.3f}")
    print(f"range:     {np.ptp(small_durations):.4f}")
    print() 
    
    print('big')
    big_durations = big[big['run'] == str(run)]['duration']
    
    print(f"mean time: {np.mean(big_durations):.3f}")
    print(f"min  time: {np.min(big_durations):.3f}")
    print(f"range:     {np.ptp(big_durations):.4f}")
    print();print('----------');print()
# Out:
# 1
#
# small
# mean time: 212.877
# min  time: 212.733
# range:     0.3831
#
# big
# mean time: 215.325
# min  time: 212.849
# range:     3.0874
#
# ----------
#
# 2
#
# small
# mean time: 215.330
# min  time: 215.199
# range:     0.3333
#
# big
# mean time: 217.755
# min  time: 215.299
# range:     2.8849
#
# ----------
#
# 3
#
# small
# mean time: 215.497
# min  time: 215.400
# range:     0.2165
#
# big
# mean time: 217.937
# min  time: 215.450
# range:     2.9011
#
# ----------
#
# 4
#
# small
# mean time: 213.605
# min  time: 213.499
# range:     0.2835
#
# big
# mean time: 215.946
# min  time: 213.583
# range:     2.7024
#
# ----------
#
# 5
#
# small
# mean time: 212.447
# min  time: 212.350
# range:     0.2329
#
# big
# mean time: 214.894
# min  time: 212.366
# range:     3.2936
#
# ----------
#
# 6
#
# small
# mean time: 215.489
# min  time: 215.350
# range:     0.2331
#
# big
# mean time: 217.880
# min  time: 215.500
# range:     2.8998
#
# ----------

# %% [markdown]
# ### Note: the above checks use:
# + first timepoint = ~first fixation cross frame flip
# + last timepoint  = ~last fixation cross frame flip

# %% [markdown]
# ### Where does the extra time come from?

# %% [markdown]
# Let's explore the duration of...
#
# + the video stimuli themselves
# + the jittered time intervals between stimuli,
# + the response periods,
# + the fixation periods at the begining and end
# + etc...
#
# and see
#
# + how they compare to the intended timings
# + how they compare between "short-run" versus "long-run" participants
# + how the jittering is affected

# %% [markdown]
# ### Prioritize: the things that matter for our experiment!
# + stimulus onset times and durations
# + jittering / time between trials
# + response period

# %% [markdown]
# # Look at average moviestim duration
#
# # average jitter difference (intended versus real)
#
# # average response period (intended versus real)
#
# # total run duration versus total expected run duration

# %% [markdown]
# # Moviestim duration

# %% [markdown]
# need to fill in code here

# %% [markdown]
# # Let's investigate the jitter timings
#
# Note: currently looking at all runs and all subjects (no exclusions) just to get a sense of how the code ran / how the timings worked out

# %%
# For each subject
# for s in subject:
    
    # 

# for each run

    

# obtain the expected jitter for each of the twenty stim

    

# obtain the actual jitter for each of the twenty stim

# %%
df_list      = []

jitter_dict  = {1:{'subject':[],'jitters':[], 'run':[]}, 
                2:{'subject':[],'jitters':[], 'run':[]}, 
                3:{'subject':[],'jitters':[], 'run':[]}, 
                4:{'subject':[],'jitters':[], 'run':[]}, 
                5:{'subject':[],'jitters':[], 'run':[]}, 
                6:{'subject':[],'jitters':[], 'run':[]}}

subject_dirs = [x for x in os.listdir('behavioral_data') if 'ubject' in x and 'unusual' not in x
                and 'disregard' not in x]

# for each person
for s in subject_dirs:
    
    print(s)
    
    csv_files = [y for y in os.listdir('behavioral_data/'+s) if y.endswith('.csv')]
    
    for logfile in os.listdir('behavioral_data/'+s):
        if not logfile.endswith('.log'):
            continue
        
        # load the log file and get run #
        log = pd.read_table('behavioral_data/'+s+'/'+logfile, header=None)

        # provided that there were scan pulses recorded
        
        if log[2].eq('Keypress: equal').any():

            run_line = log[log[2].str.contains('.csv')].iloc[0, 2]
            run = int(re.search('movie_stim_(\d)\.csv', run_line).group(1))
            
            # find start times and end times of each jitter
            
            # get the csv with the same run #############################################
            
            load_all_csvs = [ pd.read_csv('behavioral_data/'+s+'/'+x) for x in csv_files ]
            csv_runs      = []
            all_csv_new   = []
                        
            for c in load_all_csvs:
                
                if c.shape[0]>1:
                    
                    all_csv_new.append(c)
                    
                    csv_runs.append(c['run'].dropna().unique()[0])
            
            # get the index in csv_runs for the number that is this run number
            index    = csv_runs.index(float(run))
            this_csv = all_csv_new[index]
            
            #############################################################################

            # exp_start = log[log[2]=='Keypress: equal'].iloc[0][0]
            jitter_start = log[log[2]=='fix3: autoDraw = True'][0].unique()
            
            # exp_end = list(log[log[2]=='Keypress: equal'][0])[-1]
            
            jitter_end   = log[log[2]=='fix3: autoDraw = False'][0].unique()
                
            # run duration
            jitter_dict   = {'starts':list(jitter_start), 'ends':list(jitter_end)} #exp_end - exp_start
            df            = pd.DataFrame(jitter_dict)
            df['subject'] = s
            df['run']     = run
            df['real_jitter']     = df['ends'] - df['starts']
            df['expected_jitter'] = list(this_csv['jitters'].dropna())
            df['jitter_diff']     = df['real_jitter'] - df['expected_jitter']
            df_list.append(df)
            
full_df = pd.concat(df_list)
            
#             # add the total time to dict, in the key for that run (1-6)
#             jitter_dict[int(run)]['subject' ].append(s)
#             jitter_dict[int(run)]['jitters'].append(jitter_start)
#             jitter_dict[int(run)]['run'].append(run)
# Out:
# subject_17
# subject_4
# subject_1
# subject_9
# subject_22
# subject_6
# subject_21
# subject_19
# subject_8
# subject_14
# subject_16
# subject_12
# subject_11
# subject_7
# subject_5
# subject_2
# subject_20
# subject_10
# subject_15
# subject_13
# subject_3
# subject_18
# subject_23

# %%
full_df[full_df['run']==1]
# Out:
#       starts      ends     subject  run  real_jitter  expected_jitter  \
# 0   123.5566  134.0032  subject_17    1      10.4466            10.00
# 1   140.1120  144.2473  subject_17    1       4.1353             3.68
# 2   150.3120  154.8694  subject_17    1       4.5574             4.13
# 3   160.9416  164.6144  subject_17    1       3.6728             3.27
# 4   170.7001  174.0141  subject_17    1       3.3140             2.92
# ..       ...       ...         ...  ...          ...              ...
# 15  291.1774  294.4648  subject_23    1       3.2874             3.03
# 16  300.5778  305.0539  subject_23    1       4.4761             4.19
# 17  311.1443  313.9859  subject_23    1       2.8416             2.58
# 18  320.0775  323.1677  subject_23    1       3.0902             2.81
# 19  329.2940  332.6068  subject_23    1       3.3128             3.06
#
#     jitter_diff
# 0        0.4466
# 1        0.4553
# 2        0.4274
# 3        0.4028
# 4        0.3940
# ..          ...
# 15       0.2574
# 16       0.2861
# 17       0.2616
# 18       0.2802
# 19       0.2528
#
# [480 rows x 7 columns]

# %%
list(full_df['jitter_diff'])
# Out:
# [0.41629999999999967,
#  0.39310000000000045,
#  0.357800000000001,
#  0.40489999999999027,
#  0.38340000000000174,
#  0.3832000000000022,
#  0.43299999999999983,
#  0.4064999999999941,
#  0.39329999999999643,
#  0.4159000000000077,
#  0.421599999999998,
#  0.3877000000000237,
#  0.41360000000000197,
#  0.42600000000001614,
#  0.4076999999999771,
#  0.3906999999999812,
#  0.44310000000001537,
#  0.39109999999999445,
#  0.38050000000001205,
#  0.3926999999999907,
#  0.38349999999999795,
#  0.4073999999999991,
#  0.39020000000001076,
#  0.37999999999998835,
#  0.3604999999999947,
#  0.38589999999999236,
#  0.43240000000000833,
#  0.3713999999999942,
#  0.39059999999999206,
#  0.4171000000000049,
#  0.39759999999999707,
#  0.4176999999999822,
#  0.422300000000007,
#  0.4159999999999826,
#  0.43060000000002674,
#  0.3766000000000247,
#  0.3353000000000179,
#  0.3667000000000087,
#  0.33849999999998204,
#  0.34739999999999327,
#  0.40830000000000055,
#  0.4306999999999981,
#  0.4034999999999975,
#  0.42379999999999285,
#  0.37869999999999493,
#  0.4001000000000019,
#  0.2488999999999919,
#  0.2623999999999995,
#  0.24400000000001398,
#  0.24630000000000507,
#  0.26630000000000065,
#  0.2592999999999961,
#  0.25560000000001537,
#  0.27220000000001177,
#  0.2435000000000116,
#  0.2589999999999857,
#  0.2261000000000024,
#  0.2476999999999805,
#  0.2435000000000116,
#  0.2712999999999681,
#  0.16389999999999816,
#  0.25110000000000454,
#  0.2421999999999933,
#  0.265300000000003,
#  0.2441999999999993,
#  0.25499999999999545,
#  0.2635000000000005,
#  0.28940000000000055,
#  0.2325000000000017,
#  0.2723999999999904,
#  0.2634999999999792,
#  0.25320000000002096,
#  0.23189999999996713,
#  0.2786000000000399,
#  0.2752999999999872,
#  0.26729999999997744,
#  0.2663000000000011,
#  0.2336999999999989,
#  0.23510000000001696,
#  0.22819999999998686,
#  0.1658000000000044,
#  0.2514999999999965,
#  0.23639999999999972,
#  0.2752000000000048,
#  0.26089999999999947,
#  0.26079999999998904,
#  0.2615000000000052,
#  0.252200000000002,
#  0.2577999999999889,
#  0.27949999999999875,
#  0.25730000000000075,
#  0.25020000000000664,
#  0.24319999999997277,
#  0.2704999999999984,
#  0.2617999999999938,
#  0.25219999999998777,
#  0.2693999999999903,
#  0.22710000000000719,
#  0.24430000000003815,
#  0.2424000000000035,
#  ...]

# %%
full_df.groupby(['subject'],as_index=False)[['expected_jitter','real_jitter','jitter_diff']].mean()
# Out:
#        subject  expected_jitter  real_jitter  jitter_diff
# 0    subject_1         3.828786     4.241582     0.412796
# 1   subject_10         3.833583     4.221639     0.388056
# 2   subject_11         3.833583     4.218067     0.384484
# 3   subject_12         3.842929     4.238150     0.395221
# 4   subject_13         3.833583     4.223548     0.389965
# 5   subject_14         3.833583     4.235377     0.401794
# 6   subject_15         3.833583     4.227293     0.393710
# 7   subject_16         3.833583     4.241862     0.408279
# 8   subject_17         3.833583     4.230807     0.397223
# 9   subject_18         3.833583     4.084071     0.250487
# 10  subject_19         3.833583     4.089541     0.255958
# 11   subject_2         3.833583     4.225413     0.391830
# 12  subject_20         3.833583     4.094794     0.261211
# 13  subject_21         3.833583     4.083243     0.249660
# 14  subject_22         3.833583     4.079188     0.245605
# 15  subject_23         3.833583     4.088387     0.254803
# 16   subject_3         3.833583     4.233464     0.399881
# 17   subject_4         3.833583     4.225376     0.391792
# 18   subject_5         3.833583     4.228579     0.394996
# 19   subject_6         3.833583     4.226507     0.392924
# 20   subject_7         3.833583     4.239558     0.405974
# 21   subject_8         3.833583     4.239892     0.406308
# 22   subject_9         3.833583     4.225723     0.392140

# %% [markdown]
# # max jitter

# %%
# QUESTION FOR KIRSTEN: why the <10 stipulation??

full_df[full_df['expected_jitter']<10][['expected_jitter','real_jitter','jitter_diff']].max()
# Out:
# expected_jitter     9.8400
# real_jitter        10.3074
# jitter_diff         0.5013
# dtype: float64

# %% [markdown]
# # min jitter

# %%
# QUESTION FOR KIRSTEN: why the <10 stipulation??

full_df[full_df['expected_jitter']<10][['expected_jitter','real_jitter','jitter_diff']].min()
# Out:
# expected_jitter    2.0000
# real_jitter        2.2433
# jitter_diff        0.2085
# dtype: float64

# %%
print(f"On average the jitter period was {full_df['jitter_diff'].mean():.2f} seconds longer than intended")
# Out:
# On average the jitter period was 0.36 seconds longer than intended

# %% [markdown]
# #### GRAVEYARD

# %%
# get theoretical timings

theo_timing_dict = {1:{}, 2:{}, 3:{}, 4:{}, 5:{}, 6:{}}
example_subject  = 'subject_23'

# KZ NOTE: swap out subject 23 with the csv stim files from the MRI room computer
# KZ NOTE: swap out the fps 60 stimuli with the stimuli from the MRI room computer

# for each run
for file in [x for x in os.listdir('behavioral_data/'+example_subject) if 'csv' in x]:

    # load the csv
    df = pd.read_csv('behavioral_data/'+example_subject+'/'+file); run = int(df['run'][1])

    # get the total jitter durations
    theo_timing_dict[run]['jitters'] = list(df[1:21]['jitters']) 

    # get the names of the videos in that run
    theo_timing_dict[run]['videos'] = list(df[1:21]['moviestim']) 
    
    # get the number of frames in each video
    theo_timing_dict[run]['movie_frames'] = get_frames(theo_timing_dict[run]['videos'])

    # video_time = total_frames * (1/60) <-- 60 frames / second
    theo_timing_dict[run]['video_times'] = [x*(1/60) for x in theo_timing_dict[run]['movie_frames'] ]
    
    # all_other_time = ( 20 response_periods * 3 secs ) + 10s post_task_fixation
    theo_timing_dict[run]['response_periods'] = 20*3
    theo_timing_dict[run]['post_fixation']    = 10
    
    # theo_timing_dict[run]['duration'] = sum(video_times) + sum(response_periods) + post_fixation 
    theo_timing_dict[run]['duration'] = np.sum(theo_timing_dict[run]['video_times']) + np.sum(theo_timing_dict[run]['jitters']) + theo_timing_dict[run]['response_periods'] + theo_timing_dict[run]['post_fixation']
# Out:
# could not find number of frames: fps_60/1159329.bmp_pp95_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713274.bmp_pp91_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159813.bmp_pp88_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592747.bmp_pp54_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1591977.bmp_pp58_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160168.bmp_pp54_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592303.bmp_pp84_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592747.bmp_pp54_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159440.bmp_pp64_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/150474.bmp_pp57_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160168.bmp_pp54_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285993.bmp_pp67_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592303.bmp_pp84_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285993.bmp_pp67_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159813.bmp_pp88_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1591977.bmp_pp58_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159329.bmp_pp95_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/150474.bmp_pp57_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159440.bmp_pp64_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713274.bmp_pp91_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/150296.bmp_pp97_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713519.bmp_pp84_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159819.bmp_pp63_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/498396.bmp_pp152_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713707.bmp_pp63_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/150296.bmp_pp97_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285992.bmp_pp98_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159508.bmp_pp151_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713519.bmp_pp84_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713707.bmp_pp63_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592137.bmp_pp58_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160140.bmp_pp151_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592137.bmp_pp58_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160171.bmp_pp97_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159819.bmp_pp63_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160171.bmp_pp97_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285992.bmp_pp98_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160140.bmp_pp151_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159508.bmp_pp151_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/498396.bmp_pp152_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592044.bmp_pp90_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592094.bmp_pp89_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713142.bmp_pp54_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159515.bmp_pp80_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713142.bmp_pp54_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713330.bmp_pp51_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592044.bmp_pp90_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159515.bmp_pp80_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160247.bmp_pp99_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713807.bmp_pp152_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592094.bmp_pp89_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713807.bmp_pp152_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592836.bmp_pp64_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592254.bmp_pp82_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713330.bmp_pp51_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/498155.bmp_pp99_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160247.bmp_pp99_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/498155.bmp_pp99_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592254.bmp_pp82_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592836.bmp_pp64_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/497926.bmp_pp65_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159775.bmp_pp86_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713089.bmp_pp91_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285933.bmp_pp89_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/286001.bmp_pp90_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159956.bmp_pp73_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/498151.bmp_pp60_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/497926.bmp_pp65_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159606.bmp_pp151_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713089.bmp_pp91_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285933.bmp_pp89_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1591932.bmp_pp76_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/286001.bmp_pp90_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159606.bmp_pp151_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159956.bmp_pp73_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/498151.bmp_pp60_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159775.bmp_pp86_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592201.bmp_pp100_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1591932.bmp_pp76_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592201.bmp_pp100_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285948.bmp_pp64_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713285.bmp_pp53_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592530.bmp_pp75_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1593056.bmp_pp93_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713285.bmp_pp53_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713017.bmp_pp82_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592530.bmp_pp75_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159870.bmp_pp69_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713017.bmp_pp82_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160227.bmp_pp94_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159870.bmp_pp69_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1593056.bmp_pp93_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159325.bmp_pp67_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713135.bmp_pp94_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159325.bmp_pp67_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160049.bmp_pp79_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/713135.bmp_pp94_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160049.bmp_pp79_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1160227.bmp_pp94_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/285948.bmp_pp64_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1591975.bmp_pp86_L2_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592804.bmp_pp60_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159318.bmp_pp93_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159482.bmp_pp97_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1591975.bmp_pp86_L2_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159777.bmp_pp56_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592804.bmp_pp60_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159777.bmp_pp56_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159318.bmp_pp93_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592568.bmp_pp81_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159497.bmp_pp91_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592372.bmp_pp89_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592568.bmp_pp81_L1_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1593102.bmp_pp80_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159497.bmp_pp91_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592727.bmp_pp69_L3_V1_veridical_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1159482.bmp_pp97_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592372.bmp_pp89_L1_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1593102.bmp_pp80_L3_V1_scrambled_freeview_isoFalse_fps60.mp4
# could not find number of frames: fps_60/1592727.bmp_pp69_L3_V1_scrambled_freeview_isoFalse_fps60.mp4

# %%
df = pd.DataFrame(theo_timing_dict) #[1]['video_times']
df[1]['jitters']
# Out:
# [10.0,
#  3.68,
#  4.129999999999999,
#  3.27,
#  2.9200000000000017,
#  2.299999999999997,
#  4.430000000000007,
#  2.6700000000000017,
#  2.9599999999999937,
#  3.61,
#  3.1200000000000045,
#  2.9799999999999898,
#  4.8700000000000045,
#  2.640000000000015,
#  6.099999999999994,
#  3.030000000000001,
#  4.189999999999998,
#  2.579999999999984,
#  2.8100000000000023,
#  3.0600000000000023]

# %%
# template_dict = {'real':[],             'fake':[],  
#                  'judged_real':[],      'judged_fake':[],
#                  'recognized_real':[],  'recognized_fake':[],
#                  'real_judged_fake':[], 'fake_judged_real':[]}

# %%
log[log[2].str.contains('Keypress: equal')]
# Out:
#             0      1                2
# 17    27.5020  DATA   Keypress: equal
# 23    29.5019  DATA   Keypress: equal
# 24    31.5019  DATA   Keypress: equal
# 25    33.5020  DATA   Keypress: equal
# 26    35.5018  DATA   Keypress: equal
# ..        ...    ...              ...
# 321  237.5041  DATA   Keypress: equal
# 322  239.4952  DATA   Keypress: equal
# 323  241.5065  DATA   Keypress: equal
# 324  243.4998  DATA   Keypress: equal
# 325  245.5074  DATA   Keypress: equal
#
# [110 rows x 3 columns]
